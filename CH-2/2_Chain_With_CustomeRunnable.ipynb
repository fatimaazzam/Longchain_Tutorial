# %%
from langchain_openai import ChatOpenAI
import os
import load_dotenv

# This function will load all the variables from the .env file and 
# make them available in the os.environ dictionary (env variables)
load_dotenv.load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("API veriable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model='gpt-5-mini', temperature=0)
# Out:
# API veriable exists

# %% [markdown]
# # **Chain With Custom Runnable**

# %%
# Task 1 : Prompt

prompt_template = ChatPromptTemplate([
    ('system', 'You are a helpful assistence'),
    ('human', "{input}")
])

# %%
# Task - 2: LLM

llm_openai = ChatOpenAI(model='gpt-5-mini', temperature=0)

# %%
# Task - 3: String Parser

str_parser = StrOutputParser()

# %%
# Task - 4 : Custom Runnable
from langchain_core.runnables import RunnableLambda

def dictionary_maker(text:str) -> dict:
    return {'text': text}

dictionary_maker_runnable = RunnableLambda(dictionary_maker)

# %%
# Task - 5 : Template For Post

prompt_post = ChatPromptTemplate.from_messages(
    messages=[
        ('system', 'You are a social media post generator.'),
        ('human', "create a post for the following text for linkedin: {text}")
    ]
)

# %%
# Task - 6 : Generate the Post
llm_openai = ChatOpenAI(model="gpt-5-mini", temperature=0)

# %%
# Task - 7: String Parser
str_parser = StrOutputParser()

# %%
# Chain
chain = prompt_template | llm_openai | str_parser | dictionary_maker_runnable | prompt_post | llm_openai | str_parser
chain.invoke("What is the capital of Palestine?")
# Out:
# 'The State of Palestine proclaims East Jerusalem (al‑Quds) as its capital, but East Jerusalem remains under Israeli control and its status is the subject of international dispute. In practice, most Palestinian Authority administrative and government functions operate out of Ramallah, which has become the de facto administrative center.\n\nThis arrangement has practical implications for governance, service delivery, diplomatic engagement and business operations in the West Bank and Jerusalem. Understanding the distinction between de jure claims and de facto realities is important for policymakers, NGOs and companies working in the region.\n\nI welcome informed perspectives on how these dynamics affect development, stability and international cooperation in the area. #Palestine #Jerusalem #MiddleEast #Governance #Diplomacy #InternationalRelations'
