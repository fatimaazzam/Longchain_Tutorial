# %% [markdown]
# # **Chains in Langchain**

# %%
from langchain_openai import ChatOpenAI
import os
import load_dotenv

# This function will load all the variables from the .env file and 
# make them available in the os.environ dictionary (env variables)
load_dotenv.load_dotenv() 

if os.environ.get("OPENAI_API_KEY"):
    print("API veriable exists")
else:
    raise ValueError("OPENAI_API_KEY not found")

from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

llm_openai = ChatOpenAI(model='gpt-5-mini', temperature=0)
# Out:
# API veriable exists

# %% [markdown]
# # **First Chain**

# %%
# Task 1 : Prompt

prompt_template = ChatPromptTemplate([
    ('system', 'You are a helpful assistence'),
    ('human', "{input}")
])

# %%
# Task - 2: LLM

llm_openai = ChatOpenAI(model='gpt-5-mini', temperature=0)

# %%
# Task - 3: String Parser

str_parser = StrOutputParser()

# %% [markdown]
# ### **Manual Invocation**

# %%
template = prompt_template.invoke({"input": "What is the capital of Palestine?"})
res = llm_openai.invoke(template)
final_result = res.content

# %%
final_result
# Out:
# 'The State of Palestine claims East Jerusalem as its capital. In practice, however, most Palestinian governmental institutions and the Palestinian Authority operate from Ramallah (near Al-Bireh), so Ramallah functions as the administrative/de facto capital. The status of Jerusalem remains disputed and is the subject of ongoing international and Israeli–Palestinian negotiations.'

# %% [markdown]
# # **Chain Invocation**

# %%
# First Method 
chain = prompt_template | llm_openai | str_parser
chain.invoke({"input": "What is the capital of Palestine?"})
# Out:
# 'The State of Palestine designates East Jerusalem (al-Quds) as its capital. In practice, because Israel controls Jerusalem, most Palestinian governmental and diplomatic institutions operate from Ramallah in the West Bank, and many foreign missions dealing with the Palestinians are based there. International recognition varies: some countries recognize the State of Palestine and its claim to East Jerusalem, while others consider the status of Jerusalem to be a matter for final-status negotiations.'

# %%
# Second Method
from langchain_core.runnables import RunnableSequence

chain_1 = RunnableSequence( prompt_template, llm_openai, str_parser)
chain_1.invoke("What is the capital of Palestine?")
# Out:
# 'The State of Palestine proclaims East Jerusalem as its capital. In practice, because Israel controls Jerusalem, the Palestinian Authority’s main administrative offices and the presidential headquarters are in Ramallah, which serves as the de facto administrative center. Internationally the status of Jerusalem is disputed and considered unresolved pending final negotiations.'
